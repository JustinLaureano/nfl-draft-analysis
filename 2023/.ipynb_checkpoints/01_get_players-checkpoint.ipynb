# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
draft_year = 2023
base_url = 'https://www.pro-football-reference.com'

players_url = f'{base_url}/years/{draft_year}/draft.htm'
players_html = urlopen(players_url);

soup = BeautifulSoup(players_html, 'html.parser')
table = soup.find('table', id ='drafts')
table_body = table.find('tbody')
rows = table_body.find_all('tr')

# %%
def get_row_tag(row, data_stat, tag='td'):
    return row.find(tag, attrs={'data-stat': data_stat})

def get_row_tag_text(row, data_stat, tag='td'):
    return get_row_tag(row, data_stat, tag).text

def get_row_link_text(row, data_stat):
    return get_row_tag(row, data_stat).find('a').text

# %%
df = pd.DataFrame(columns=['player', 'player_link', 'rnd', 'pick', 'tm', 'pos', 'age', 'college', 'height_in', 'weight_lbs', 'height_cm', 'weight_kg'])

for row in rows:
    if (row.get('class') and 'thead' in row.get('class')):  
        continue

    player_tag = get_row_tag(row, 'player')
    player_link_tag = player_tag.find('a')

    player = player_link_tag.text
    player_link = player_link_tag.get('href')

    rnd = get_row_tag_text(row, 'draft_round', tag='th')
    pick = get_row_tag_text(row, 'draft_pick')
    tm = get_row_link_text(row, 'team')
    pos = get_row_tag_text(row, 'pos')
    age = get_row_tag_text(row, 'age')
    college = get_row_link_text(row, 'college_id')

    
    height_in = ''
    weight_lbs = ''
    height_cm = ''
    weight_kg = ''
    
    player_data = {
        'player': player,
        'player_link': player_link,
        'rnd': rnd,
        'pick': pick,
        'tm': tm,
        'pos': pos,
        'age': age,
        'college': college,
        'height_in': height_in,
        'weight_lbs': weight_lbs,
        'height_cm': height_cm,
        'weight_kg': weight_kg
    }

    df.loc[len(df.index)] = player_data
    

df.to_csv('players.csv');
df.head(10)
# Out:
#                player              player_link rnd pick   tm  pos age  \
# 0         Bryce Young  /players/Y/YounBr01.htm   1    1  CAR   QB  22
# 1         C.J. Stroud  /players/S/StroCJ00.htm   1    2  HOU   QB  21
# 2       Will Anderson  /players/A/AndeWi01.htm   1    3  HOU   LB  22
# 3  Anthony Richardson  /players/R/RichAn03.htm   1    4  IND   QB  21
# 4   Devon Witherspoon  /players/W/WithDe00.htm   1    5  SEA   DB  22
# 5       Paris Johnson  /players/J/JohnPa03.htm   1    6  ARI   OL  22
# 6        Tyree Wilson  /players/W/WilsTy01.htm   1    7  LVR  OLB  23
# 7      Bijan Robinson  /players/R/RobiBi01.htm   1    8  ATL   RB  21
# 8        Jalen Carter  /players/C/CartJa05.htm   1    9  PHI   DL  22
# 9      Darnell Wright  /players/W/WrigDa00.htm   1   10  CHI   OL  22
#
#       college height_in weight_lbs height_cm weight_kg
# 0     Alabama
# 1    Ohio St.
# 2     Alabama
# 3     Florida
# 4    Illinois
# 5    Ohio St.
# 6  Texas Tech
# 7       Texas
# 8     Georgia
# 9   Tennessee
