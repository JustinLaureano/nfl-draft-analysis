# %%
import pandas as pd

# %%
df = pd.read_csv('players_size.csv')
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0              player  \
# 0             0           0         Bryce Young
# 1             1           1         C.J. Stroud
# 2             2           2       Will Anderson
# 3             3           3  Anthony Richardson
# 4             4           4   Devon Witherspoon
# 5             5           5       Paris Johnson
# 6             6           6        Tyree Wilson
# 7             7           7      Bijan Robinson
# 8             8           8        Jalen Carter
# 9             9           9      Darnell Wright
#
#                                           player_url  rnd  pick   tm  pos  \
# 0  https://www.pro-football-reference.com/players...    1     1  CAR   QB
# 1  https://www.pro-football-reference.com/players...    1     2  HOU   QB
# 2  https://www.pro-football-reference.com/players...    1     3  HOU   LB
# 3  https://www.pro-football-reference.com/players...    1     4  IND   QB
# ...

# %%
import seaborn as sns

sns.scatterplot(x="weight_kg", y="height_cm", data=df, hue="pos")
# Out:
# <Axes: xlabel='weight_kg', ylabel='height_cm'>

# %%
df.plot.scatter(x='height_in', y='weight_lb')
# Out:
# <Axes: xlabel='height_in', ylabel='weight_lb'>
